# %% [markdown]
# # Import packages and data

# %%
import pandas as pd
import numpy as np

# %%
in_path = "/content/drive/MyDrive/Spring 2023/Data Visualization/Project/college_rankings_merged_with_ScoreCard_data.xlsx"
df = pd.read_excel(in_path, sheet_name = "Sheet1")

# %% [markdown]
# # Base columns

# %%
meta_cols = ['year','INSTNM'] 
world_cols = ['world_rank_THE','world_rank_RUR','world_rank_CWUR','score_THE','score_RUR','score_CWUR']

# %% [markdown]
# # Feature Engineering

# %%
UGDS_cols = [
    'UGDS_WHITE',
    'UGDS_BLACK',
    'UGDS_HISP',
    'UGDS_ASIAN',
    'UGDS_AIAN',
    'UGDS_NHPI',
    'UGDS_2MOR',
    'UGDS_NRA',
    'UGDS_UNKN',
]
df['UGDS_diversity'] = -1 * df[UGDS_cols].var(axis=1)

# %%
feature_cols = [
    'international_students_THE',
    'UGDS_diversity',
]

df = df[meta_cols+world_cols+feature_cols]
df['coltype'] = "raw"

# %%
df
# Out:
#      year                                      INSTNM world_rank_THE  \
# 0    2012                          Harvard University              2
# 1    2012                         Stanford University              2
# 2    2012       Massachusetts Institute of Technology              7
# 3    2012                       University of Chicago              9
# 4    2012           University of California-Berkeley             10
# ..    ...                                         ...            ...
# 678  2015  University of North Carolina at Greensboro            NaN
# 679  2015          University of Southern Mississippi            NaN
# 680  2015                  University of North Dakota            NaN
# 681  2015          The University of Texas at El Paso            NaN
# 682  2015             University of California-Merced            NaN
#
#      world_rank_RUR  world_rank_CWUR score_THE  score_RUR  score_CWUR  \
# 0               2.0              1.0      93.9     98.500      100.00
# 1               3.0              3.0      93.9     96.610       89.50
# 2               4.0              2.0      92.3     95.174       91.67
# 3               6.0             11.0      90.2     94.456       73.82
# 4              49.0             10.0      89.8     82.240       78.55
# ..              ...              ...       ...        ...         ...
# 678             NaN            897.0       NaN        NaN       44.13
# 679             NaN            901.0       NaN        NaN       44.13
# 680             NaN            913.0       NaN        NaN       44.12
# 681             NaN            929.0       NaN        NaN       44.10
# 682             NaN            936.0       NaN        NaN       44.09
#
#      international_students_THE  UGDS_diversity coltype
# 0                          0.25       -0.019831     raw
# 1                          0.22       -0.013371     raw
# 2                          0.33       -0.014674     raw
# 3                          0.21       -0.017655     raw
# 4                          0.15       -0.018110     raw
# ..                          ...             ...     ...
# 678                         NaN       -0.033599     raw
# 679                         NaN       -0.045082     raw
# 680                         NaN       -0.069889     raw
# 681                         NaN       -0.073334     raw
# 682                         NaN       -0.023015     raw
#
# [683 rows x 11 columns]

# %%
# df['female_male_ratio_THE'] = df['female_male_ratio_THE'].astype("string")
# df['female_proportion'] = df[~df['female_male_ratio_THE'].isna()]['female_male_ratio_THE']

# %% [markdown]
# # Create min-max scaled columns

# %%
df_copy = df.copy()
df_copy[feature_cols] = (df_copy[feature_cols] - df_copy[feature_cols].min())/(df_copy[feature_cols].max() - df_copy[feature_cols].min())

# %%
df_copy['coltype'] = 'scaled'
df = pd.concat([df,df_copy]).reset_index(drop=True)

# %% [markdown]
# # Create weight columns

# %%
df_copy = df[df['coltype'] == 'scaled'].copy()
df_copy[feature_cols] = df_copy[feature_cols].var()/df_copy[feature_cols].var().sum()
# df[weight_cols] = 1/len(weight_cols)

# %%
df_copy['coltype'] = 'weight'
df = pd.concat([df,df_copy]).reset_index(drop=True)

# %% [markdown]
# # Create score columns

# %%
df_copy = df[df['coltype'] == 'raw'].copy()
for col in feature_cols:
  df_copy[col] = df[df['coltype'] == 'scaled'][col].reset_index(drop=True) * \
  df[df['coltype'] == 'weight'][col].reset_index(drop=True)

# %%
df_copy['coltype'] = 'score'
df = pd.concat([df,df_copy]).reset_index(drop=True)

# %% [markdown]
# # Create diversity columns

# %%
df_copy = df[df['coltype'] == 'score'][meta_cols+feature_cols].copy()
df_copy['diversity_index'] = df_copy[feature_cols].sum(axis=1)
df_copy['diversity_index'] = (df_copy['diversity_index'] - df_copy['diversity_index'].min())/\
(df_copy['diversity_index'].max() - df_copy['diversity_index'].min())
df_copy['diversity_rank'] = df_copy['diversity_index'].rank(ascending=False)
df_copy['diversity_year_rank'] = df_copy.groupby('year')['diversity_index'].rank(ascending=False)

# %%
df_copy = df_copy[meta_cols+['diversity_index','diversity_rank','diversity_year_rank']]
df = df.merge(df_copy,on=['year','INSTNM'])

# %%
df['diversity_index'] = df.mask(df['coltype'] != 'score')['diversity_index']

# %%
df = df.sort_values(by=['year','diversity_year_rank'])

# %% [markdown]
# # Export

# %%
out_path = '/content/drive/MyDrive/Spring 2023/Data Visualization/Project/diversity_df_v2.csv'
df.to_csv(out_path,index=0)

# %%
df
# Out:
#       year                                 INSTNM world_rank_THE  \
# 8     2012  Massachusetts Institute of Technology              7
# 9     2012  Massachusetts Institute of Technology              7
# 10    2012  Massachusetts Institute of Technology              7
# 11    2012  Massachusetts Institute of Technology              7
# 48    2012             Carnegie Mellon University             21
# ...    ...                                    ...            ...
# 2159  2015                     Yeshiva University            186
# 2640  2015                      Howard University            NaN
# 2641  2015                      Howard University            NaN
# 2642  2015                      Howard University            NaN
# 2643  2015                      Howard University            NaN
#
#       world_rank_RUR  world_rank_CWUR score_THE  score_RUR  score_CWUR  \
# 8                4.0              2.0      92.3     95.174       91.67
# 9                4.0              2.0      92.3     95.174       91.67
# 10               4.0              2.0      92.3     95.174       91.67
# 11               4.0              2.0      92.3     95.174       91.67
# 48              33.0             43.0      78.4     84.669       51.60
# ...              ...              ...       ...        ...         ...
# 2159            81.0            171.0      46.7     80.001       48.11
# 2640             NaN            719.0       NaN        NaN       44.33
# 2641             NaN            719.0       NaN        NaN       44.33
# 2642             NaN            719.0       NaN        NaN       44.33
# 2643             NaN            719.0       NaN        NaN       44.33
#
#       international_students_THE  UGDS_diversity coltype  diversity_index  \
# 8                       0.330000       -0.014674     raw              NaN
# 9                       0.941176        0.965848  scaled              NaN
# 10                      0.432603        0.567397  weight              NaN
# 11                      0.407156        0.548020   score         0.979116
# 48                      0.350000       -0.018775     raw              NaN
# ...                          ...             ...     ...              ...
# 2159                    0.076342        0.000000   score         0.050820
# 2640                         NaN       -0.089351     raw              NaN
# 2641                         NaN        0.069674  scaled              NaN
# 2642                    0.432603        0.567397  weight              NaN
# 2643                         NaN        0.039533   score         0.011939
#
#       diversity_rank  diversity_year_rank
# 8                4.0                  1.0
# 9                4.0                  1.0
# 10               4.0                  1.0
# 11               4.0                  1.0
# 48               5.0                  2.0
# ...              ...                  ...
# 2159           681.0                207.0
# 2640           682.0                208.0
# 2641           682.0                208.0
# 2642           682.0                208.0
# 2643           682.0                208.0
#
# [2732 rows x 14 columns]
